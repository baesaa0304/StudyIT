# %% [markdown]
# <a href="https://colab.research.google.com/github/baesunyoung34/Python/blob/main/py18_mpg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 패키지 임포츠

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #mpg 데이터셋

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# mpg(Mile Per Gallon) dataset
# * mpg : 연비
# * cylinders : 실린더 개수
# * displacement : 배기량
# * horsepower : 마력
# * weight : 자동차 무게
# * acceleration : 가속도.
# * model_year : 자동차 생산 연도
# * origin : 자동차 생산지
# * name : 자동차 이름

# %% [markdown]
# * mng 데이터 셋 탐색.
# * mpg _ displacement scatter plot
# * 2x2 subplot을 생성 scatter plot.
#     - mpg ~ cylinders
#     - mpg ~ horsepower
#     - mpg ~ weight
#     - mpg - acceleration
# * cylinders 별 mpg 평균 막대 그래프
# * cylinders 별 mpg box plot
# * origin별 cylinders별 mpg box plot
# * origin 별 cylinders 별 mpg 평균 막대 그래프

# %% [markdown]
# # 데이터 탐색

# %%
mpg.describe() # 숫자 타입 변수들의 기술 통계량
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# ## 연속형 변수 탐색

# %%
sns.histplot(data=mpg, x='mpg')

plt.show()

# %%
sns.boxplot(data=mpg, x='mpg')

plt.show()

# %% [markdown]
# # 카테고리 타입 변수 탐색

# %%
# origin(자동차 생산 지역) 빈도수
mpg.origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
sns.countplot(data=mpg, x ='origin')
plt.show()

# %%
#cylinders
mpg.cylinders.value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
sns.countplot(data=mpg, x ='cylinders')
plt.show()

# %%
#model_year 빈도수
mpg.model_year.values_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-731d6b8d30f7> in <cell line: 2>()
#       1 #model_year 빈도수
# ----> 2 mpg.model_year.values_counts()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'values_counts'

# %%
sns.countplot(data=mpg, x='model_year')
plt.show()

# %% [markdown]
# #연비에 영향을 미치는 변수

# %% [markdown]
# ##mpg(연비) ~ displacement(배기량)

# %%
sns.scatterplot(data=mpg, x='displacement' , y='mpg')
plt.show()

# %%
sns.scatterplot(data=mpg, x= 'displacement' , y='mpg', hue='origin')
plt.show()

# %%
variables = ['cylinders' , 'horsepower', 'weight' , 'acceleration'] # 독립변수

# 2x2 sublot들을 생성
fig, ax = plt.subplots(nrows=2, ncols=2)

#각각의 subplot에 산점도 그리기:
for i in range(2):
    for j in range(2):
        idx = 2 * i + j
        sns.scatterplot(data=mpg, x=variables[idx],y='mpg', ax=ax[i, j])
plt.show()

# %% [markdown]
# ## 상관 관계, 상관 계수

# %%
sns.pairplot(data=mpg)
plt.show()
